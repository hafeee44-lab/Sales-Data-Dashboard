# %%
import pandas as pd

df = pd.read_csv("../data/raw/Sample-Superstore.csv")
df.head()
# Out:
#    csvbase_row_id  ﻿Row ID        Order ID  Order Date   Ship Date  \
# 0               1        1  CA-2016-152156  2016-11-08  2016-11-11
# 1               2        2  CA-2016-152156  2016-11-08  2016-11-11
# 2               3        3  CA-2016-138688  2016-06-12  2016-06-16
# 3               4        4  US-2015-108966  2015-10-11  2015-10-18
# 4               5        5  US-2015-108966  2015-10-11  2015-10-18
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df = df.drop(columns="csvbase_row_id")

df = df.rename(columns={"﻿Row ID": "Row ID"})

df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = df.drop(columns="csvbase_row_id")
#       2
#       3 df = df.rename(columns={"﻿Row ID": "Row ID"})
#       4
#
# File ~/Projects/Data Analysis Project/.venv/lib/python3.14/site-packages/pandas/core/frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~/Projects/Data Analysis Project/.venv/lib/python3.14/site-packages/pandas/core/generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
df = df.rename(columns={"﻿Row ID": "Row ID"})

df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   datetime64[us]
#  3   Ship Date      9994 non-null   datetime64[us]
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %%
df.to_csv("../data/processed/superstore_clean.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.to_csv("../data/processed/superstore_clean.csv", index=False)
#
# File ~/Projects/Data Analysis Project/.venv/lib/python3.14/site-packages/pandas/core/generic.py:3976, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3972             float_format=float_format,
#    3973             decimal=decimal,
#    3974         )
#    3975
# -> 3976         return DataFrameRenderer(formatter).to_csv(
#    3977             path_or_buf,
#    3978             lineterminator=lineterminator,
#    3979             sep=sep,
#
# ...

# %%
df.to_csv("../data/processed/superstore_clean.csv", index=False)

# %%
df.to_csv("../data/processed/superstore_clean.csv", index=False)
